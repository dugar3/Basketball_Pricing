# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

from urllib.request import urlopen
import time

import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
years = list(range(2004, 2022))

# %% [markdown]
# ## Functions

# %%
def get_NBA_year_stats(year):

    url = f"https://www.basketball-reference.com/leagues/NBA_{year}_advanced.html"

    r = requests.get(url)
    r_html = r.text
    soup = BeautifulSoup(r_html,'html.parser')
    table=soup.find_all(class_="full_table")
    
    
    # Extracting List of column names
    head=soup.find(class_="thead")
    column_names_raw=[head.text for item in head][0]
    column_names_polished=column_names_raw.replace("\n",",").split(",")[2:-1]
    
    
    players=[]
    
    for i in range(len(table)):

        player_=[]

        for td in table[i].find_all("td"):
            player_.append(td.text)

        players.append(player_)


    df=pd.DataFrame(players, columns=column_names_polished)
    #cleaning the player's name from occasional special characters
    df.Player=df.Player.str.replace('*', '')
    
    df = df[['Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'OWS', 'DWS', 'WS', 'WS/48', 'VORP']]
    df.Age = df.Age.astype(float)
    df.G = df.G.astype(float)
    df.MP = df.MP.astype(float)
    df.OWS = df.OWS.astype(float)
    df.DWS = df.DWS.astype(float)
    df.WS = df.WS.astype(float)
    df['WS/48'] = df['WS/48']
    df.VORP = df.VORP
    
    return df

# %%
def scrape_draft_data(year):
    
    draft_columns=['Pk', 'Tm', 'Player', 'College', 'Yrs', 'G', 
                   'MP', 'PTS', 'TRB', 'AST', 'FG%', '3P%', 'FT%', 
                   'MP', 'PTS', 'TRB', 'AST', 'WS', 'WS/48', 'BPM', 'VORP']
    final_df=pd.DataFrame(columns=draft_columns)
    

    url = f"https://www.basketball-reference.com/draft/NBA_{year}.html"
    html = urlopen(url)
    soup= BeautifulSoup(html, features = 'lxml')
    # get rows from table
    rows = soup.findAll('tr')[0:]
    rows_data = [[td.getText() for td in rows[i].findAll('td')]
                 for i in range(len(rows))]
    #placing data in a DataFrame
    df_1 = pd.DataFrame(rows_data,columns=draft_columns)

    final_df=pd.concat([final_df,df_1])
    final_df.dropna(axis = 0, subset = ['Player'], inplace = True)
    final_df['Draft_Year'] = year
    return final_df

# %%
def get_NBA_year_salary(year):
    year2 = year+1
    url = f"https://hoopshype.com/salaries/players/{year}-{year2}/"
    html = urlopen(url)
    soup= BeautifulSoup(html, features = 'lxml')
    # get rows from table
    rows = soup.findAll('tr')[0:]
    rows_data = [[td.getText().strip() for td in rows[i].findAll('td')]
                 for i in range(len(rows))]
    headers = rows_data.pop(0)
    df = pd.DataFrame(rows_data, columns=headers)
    df.drop(columns=df.columns[[0, 3]], axis=1,  inplace=True)
    df.columns = ['Player', 'Salary']
    df['Salary'] = df['Salary'].str.replace(r'\$', '')
    df['Salary'] = df['Salary'].str.replace(r',', '')
    df['Salary'] = df['Salary'].astype(float)
    df['Year'] = year
    return df

# %%
all_data = pd.DataFrame()
draft_data = pd.DataFrame()
for i in years:
    print(i)
    data = get_NBA_year_stats(i).merge(get_NBA_year_salary(i), 
                                       how = 'outer', on = 'Player')
    draft = scrape_draft_data(i)
    all_data = pd.concat([all_data, data], ignore_index= True)
    draft_data = pd.concat([draft_data, draft], ignore_index= True)
    time.sleep(60)

all_data = all_data.merge(draft_data, how = 'outer', on = 'Player')
# Out:
# 2004
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021

# %%
all_data
# Out:
#                     Player  Pos   Age Tm_x   G_x    MP_x  OWS  DWS  WS_x  \
# 0      Shareef Abdur-Rahim   PF  27.0  TOT  85.0  2684.0  6.1  2.0   8.1
# 1      Shareef Abdur-Rahim   PF  28.0  POR  54.0  1867.0  3.9  1.5   5.4
# 2      Shareef Abdur-Rahim   PF  29.0  SAC  72.0  1961.0  4.0  2.2   6.2
# 3      Shareef Abdur-Rahim    C  30.0  SAC  80.0  2015.0  1.1  1.7   2.8
# 4      Shareef Abdur-Rahim   PF  31.0  SAC   6.0    51.0  0.0  0.0   0.0
# ...                    ...  ...   ...  ...   ...     ...  ...  ...   ...
# 11503    Marcus Zegarowski  NaN   NaN  NaN   NaN     NaN  NaN  NaN   NaN
# 11504       Filip Petrušev  NaN   NaN  NaN   NaN     NaN  NaN  NaN   NaN
# 11505   Brandon Boston Jr.  NaN   NaN  NaN   NaN     NaN  NaN  NaN   NaN
# 11506      Balša Koprivica  NaN   NaN  NaN   NaN     NaN  NaN  NaN   NaN
# 11507         RaiQuan Gray  NaN   NaN  NaN   NaN     NaN  NaN  NaN   NaN
#
#       WS/48_x VORP_x      Salary    Year   Pk Tm_y        College  Yrs  G_y  \
# 0        .145    2.4  14625000.0  2004.0  NaN  NaN            NaN  NaN  NaN
# 1        .139    1.4   5000000.0  2005.0  NaN  NaN            NaN  NaN  NaN
# 2        .152    1.4   5400000.0  2006.0  NaN  NaN            NaN  NaN  NaN
# 3        .067   -0.2   5800000.0  2007.0  NaN  NaN            NaN  NaN  NaN
# 4      -0.005   -0.1         NaN     NaN  NaN  NaN            NaN  NaN  NaN
# ...       ...    ...         ...     ...  ...  ...            ...  ...  ...
# 11503     NaN    NaN         NaN     NaN   49  BRK      Creighton
# 11504     NaN    NaN         NaN     NaN   50  PHI        Gonzaga
# 11505     NaN    NaN         NaN     NaN   51  MEM       Kentucky    2   73
# 11506     NaN    NaN         NaN     NaN   57  CHO  Florida State
# 11507     NaN    NaN         NaN     NaN   59  BRK  Florida State    1    1
#
#        MP_y  PTS  TRB  AST   FG%   3P%    FT%  MP_y   PTS  TRB  AST WS_y  \
# 0       NaN  NaN  NaN  NaN   NaN   NaN    NaN   NaN   NaN  NaN  NaN  NaN
# 1       NaN  NaN  NaN  NaN   NaN   NaN    NaN   NaN   NaN  NaN  NaN  NaN
# 2       NaN  NaN  NaN  NaN   NaN   NaN    NaN   NaN   NaN  NaN  NaN  NaN
# 3       NaN  NaN  NaN  NaN   NaN   NaN    NaN   NaN   NaN  NaN  NaN  NaN
# 4       NaN  NaN  NaN  NaN   NaN   NaN    NaN   NaN   NaN  NaN  NaN  NaN
# ...     ...  ...  ...  ...   ...   ...    ...   ...   ...  ...  ...  ...
# 11503
# 11504
# 11505  1008  486  141   71  .394  .329   .800  13.8   6.7  1.9  1.0  0.6
# 11506
# 11507    35   16    9    7  .500  .400  1.000  35.0  16.0  9.0  7.0  0.1
#
#       WS/48_y   BPM VORP_y  Draft_Year
# 0         NaN   NaN    NaN         NaN
# 1         NaN   NaN    NaN         NaN
# 2         NaN   NaN    NaN         NaN
# 3         NaN   NaN    NaN         NaN
# 4         NaN   NaN    NaN         NaN
# ...       ...   ...    ...         ...
# 11503                           2021.0
# 11504                           2021.0
# 11505    .030  -3.0   -0.3      2021.0
# 11506                           2021.0
# 11507    .106  -2.0    0.0      2021.0
#
# [11508 rows x 34 columns]

# %%
all_data.dropna(subset=['Salary','Year']).reset_index(drop=True)
# Out:
#                    Player  Pos   Age Tm_x   G_x    MP_x  OWS  DWS  WS_x  \
# 0     Shareef Abdur-Rahim   PF  27.0  TOT  85.0  2684.0  6.1  2.0   8.1
# 1     Shareef Abdur-Rahim   PF  28.0  POR  54.0  1867.0  3.9  1.5   5.4
# 2     Shareef Abdur-Rahim   PF  29.0  SAC  72.0  1961.0  4.0  2.2   6.2
# 3     Shareef Abdur-Rahim    C  30.0  SAC  80.0  2015.0  1.1  1.7   2.8
# 4     Shareef Abdur-Rahim  NaN   NaN  NaN   NaN     NaN  NaN  NaN   NaN
# ...                   ...  ...   ...  ...   ...     ...  ...  ...   ...
# 9221       Jordan Schakel  NaN   NaN  NaN   NaN     NaN  NaN  NaN   NaN
# 9222       Jordan Goodwin  NaN   NaN  NaN   NaN     NaN  NaN  NaN   NaN
# 9223          Craig Sword  NaN   NaN  NaN   NaN     NaN  NaN  NaN   NaN
# 9224      Jaime Echenique  NaN   NaN  NaN   NaN     NaN  NaN  NaN   NaN
# 9225       Zavier Simpson  NaN   NaN  NaN   NaN     NaN  NaN  NaN   NaN
#
#      WS/48_x VORP_x      Salary    Year   Pk Tm_y College  Yrs  G_y MP_y  PTS  \
# 0       .145    2.4  14625000.0  2004.0  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 1       .139    1.4   5000000.0  2005.0  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 2       .152    1.4   5400000.0  2006.0  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 3       .067   -0.2   5800000.0  2007.0  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 4        NaN    NaN   6600000.0  2009.0  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# ...      ...    ...         ...     ...  ...  ...     ...  ...  ...  ...  ...
# 9221     NaN    NaN     53176.0  2021.0  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 9222     NaN    NaN     53176.0  2021.0  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 9223     NaN    NaN     53176.0  2021.0  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 9224     NaN    NaN     53176.0  2021.0  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 9225     NaN    NaN     37223.0  2021.0  NaN  NaN     NaN  NaN  NaN  NaN  NaN
#
#       TRB  AST  FG%  3P%  FT% MP_y  PTS  TRB  AST WS_y WS/48_y  BPM VORP_y  \
# 0     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN    NaN
# 1     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN    NaN
# 2     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN    NaN
# 3     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN    NaN
# 4     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN    NaN
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...     ...  ...    ...
# 9221  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN    NaN
# 9222  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN    NaN
# 9223  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN    NaN
# 9224  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN    NaN
# 9225  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN  NaN    NaN
#
#       Draft_Year
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 9221         NaN
# 9222         NaN
# 9223         NaN
# 9224         NaN
# 9225         NaN
#
# [9226 rows x 34 columns]

# %%
9226/18
# Out:
# 512.5555555555555

# %%
# http://bkref.com/pi/shareit/jjQt1
